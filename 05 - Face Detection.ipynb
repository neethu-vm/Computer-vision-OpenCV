# %%
import cv2

# Load the cascade
face_cascade = cv2.CascadeClassifier('/home/neethu/machine learning datas/Deep learning/face detection/haarcascade_frontalface_default.xml')

# %%
face_cascade
# Out:
# <CascadeClassifier 0x7f3bf9112550>

# %%
type(face_cascade)
# Out:
# cv2.CascadeClassifier

# %%
# Read the input image
img = cv2.imread('/home/neethu/machine learning datas/Deep learning/face detection/peoples.png',cv2.COLOR_BGR2RGB)

# %%
# Convert into grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
# ?face_cascade.detectMultiScale

# %%
# Detect faces
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1,minNeighbors=4,minSize = (10,10))

# %%
faces
# Out:
# array([[ 80,  46,  63,  63],
#        [270,  73,  62,  62],
#        [455,  77,  59,  59],
#        [341,  93,  57,  57],
#        [148, 119,  57,  57],
#        [414, 248,  30,  30]], dtype=int32)

# %%
len(faces)
# Out:
# 6

# %%
# Draw rectangle around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 0, 0), 2)

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %% [markdown]
# ### Face Detection from webcam or Video Feed

# %%
video_capture = cv2.VideoCapture('/home/neethu/machine learning datas/Deep learning/face detection/people.mp4') #To Read video 0 for webcam else you can give the video path

# %%
#video_capture = cv2.VideoCapture(0) - This is to use webcam feed

# %%
video_capture
# Out:
# <VideoCapture 0x7f3bc5eefa70>

# %%
 
while True:
    # Capture frame-by-frame
    ret, frame = video_capture.read()

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = face_cascade.detectMultiScale(
        gray,
        scaleFactor=1.07,
        minNeighbors=4,
        minSize=(10, 10)
    )

    # Draw a rectangle around the faces
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)

    # Display the resulting frame
    cv2.imshow('Video', frame)

    if cv2.waitKey(1) & 0xFF == 27:
        break
# When everything is done, release the capture
video_capture.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-13-4aab2fd67007> in <module>
#       3     ret, frame = video_capture.read()
#       4
# ----> 5     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#       6
#       7     faces = face_cascade.detectMultiScale(
#
# error: OpenCV(4.5.2) /tmp/pip-req-build-eirhwqtr/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %% [markdown]
# ### Detecting Eyes

# %%
eye_cascade = cv2.CascadeClassifier('/home/neethu/machine learning datas/Deep learning/face detection/haarcascade_eye.xml')

# %%
img = cv2.imread('/home/neethu/machine learning datas/Deep learning/face detection/peoples1.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.1, 10,minSize = (15,15))
# When no faces detected, face_classifier returns and empty tuple
if faces is ():
    print("No Face Found")
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),2)
    roi_gray = gray[y:y+h, x:x+w] #cropiing the face
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray,scaleFactor=1.01,minNeighbors=4,minSize=(1,1)) #checking for eye within the face
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(255,0,0),2)
# Out:
# <>:5: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:5: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-15-d2fd4f1b0fc1>:5: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():

# %%
plt.imshow(img)

# %% [markdown]
# ### Detecting Eyes from Video

# %%
#video_capture = cv2.VideoCapture(0)
video_capture = cv2.VideoCapture('/home/neethu/machine learning datas/Deep learning/face detection/laugh.mp4')

while True:
    # Capture frame-by-frame
    ret, frame = video_capture.read()
    print(ret)

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = face_cascade.detectMultiScale(
        gray,
        scaleFactor=1.1,
        minNeighbors=9,
        minSize=(10, 10)
    )
    print(faces)
    # Draw a rectangle around the faces
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
        #cv2.rectangle(img,(x,y),(x+w,y+h),(127,0,255),2)
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = frame[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray,scaleFactor=1.1,minNeighbors=4,minSize=(10,10))
        for (ex,ey,ew,eh) in eyes:
            cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(255,255,0),2)
        

    # Display the resulting frame
    cv2.imshow('Video', frame)

    if cv2.waitKey(1) & 0xFF == 27:
        break
# When everything is done, release the capture
video_capture.release()
cv2.destroyAllWindows()
# Out:
# True
# [[318  50 123 123]]
# True
# [[316  49 126 126]]
# True
# [[317  50 124 124]]
# True
# [[317  51 123 123]]
# True
# [[317  50 124 124]]
# True
# [[317  50 124 124]]
# True
# [[316  51 124 124]]
# True
# [[314  51 128 128]]
# True
# [[314  51 127 127]]
# True
# [[315  53 125 125]]
# True
# [[317  54 122 122]]
# True
# [[316  55 123 123]]
# True
# [[314  53 128 128]]
# True
# [[313  53 130 130]]
# True
# [[316  56 124 124]]
# True
# [[318  58 123 123]]
# True
# [[318  58 122 122]]
# True
# [[317  59 123 123]]
# True
# [[316  58 126 126]]
# True
# [[316  59 126 126]]
# True
# [[317  60 124 124]]
# True
# [[173  70  84  84]
#  [316  60 125 125]]
# True
# [[167  63 100 100]
#  [317  61 124 124]]
# True
# [[317  62 123 123]]
# True
# [[316  62 124 124]]
# True
# [[317  62 125 125]]
# True
# [[318  63 122 122]]
# True
# [[168  65 101 101]
#  [318  64 122 122]]
# True
# [[317  64 124 124]]
# True
# [[317  64 123 123]]
# True
# [[317  65 123 123]]
# True
# [[317  65 122 122]]
# True
# ...

# %%
#END
