# %%
import cv2

# Load the cascade
body_cascade = cv2.CascadeClassifier('/home/neethu/machine learning datas/Deep learning/full body detection/haarcascade_fullbody.xml')

# %%
# Read the input image
img = cv2.imread('/home/neethu/machine learning datas/Deep learning/full body detection/street.jpg')
# Convert into grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
# Detect humans
humans = body_cascade.detectMultiScale(gray)

# %%
humans
# Out:
# array([[1938, 1291,  721, 1442],
#        [2422,  906,  895, 1790],
#        [1237, 1098,  930, 1860]], dtype=int32)

# %%
# Draw rectangle around the humans
for (x, y, w, h) in humans:
    cv2.rectangle(img, (x, y), (x+w, y+h), (255, 255, 255), 5)

# %%
img.shape
# Out:
# (3072, 4608, 3)

# %%
#Image Resizing
scale_percent = 30 # percent of original size
width = int(img.shape[1] * scale_percent / 100)
height = int(img.shape[0] * scale_percent / 100)
dim = (width, height)
# resize image
img= cv2.resize(img, dim, interpolation = cv2.INTER_AREA)

# %%
img.shape
# Out:
# (921, 1382, 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
# Show Image
#cv2.namedWindow('Street', cv2.WINDOW_AUTOSIZE)
cv2.imshow('Street', img)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
cv2.imwrite('/home/neethu/machine learning datas/Deep learning/full body detection/street1.jpg',img)
# Out:
# True
